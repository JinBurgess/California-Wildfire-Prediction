# %%
import sys
sys.path.append('../')

from common_imports import *
from common_functions import *

# %% [markdown]
# Merging each year into one data frame

# %%
dir_path = "weather_data/Cities/Salinas"
df = merge_files(dir_path)
df.sort_values(by='datetime').head(5)
# Out:
#                   name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Salinas, California  2013-04-01     17.8     12.0  14.3          17.8
# 1  Salinas, California  2013-04-02     17.7      9.8  12.7          17.7
# 2  Salinas, California  2013-04-03     23.7      9.0  12.7          23.7
# 3  Salinas, California  2013-04-04     18.8     10.8  13.7          18.8
# 4  Salinas, California  2013-04-05     18.1     12.9  14.8          18.1
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          12.0       14.3  10.6      79.6  ...         21.9        8
# 1           9.6       12.7   9.6      82.5  ...         23.6        9
# 2           7.2       12.4   9.5      83.2  ...         21.0        9
# 3          10.8       13.7  11.1      84.7  ...         13.7        5
# 4          12.9       14.8  10.4      76.4  ...         21.6        8
#
#    severerisk              sunrise               sunset  moonphase  \
# ...

# %%
df['name'] = 'Salinas, CA'

# %%
df.to_csv("weather_data/Merged_City/SalinasMerged.csv", index = False)

# %% [markdown]
# Merge wildfire incident with weather data
